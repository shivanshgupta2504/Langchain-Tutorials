# %%
from langchain_openai import ChatOpenAI
from langchain.schema.runnable import RunnableSequence, RunnableParallel, RunnablePassthrough, RunnableLambda, RunnableBranch
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
from dotenv import load_dotenv

# %% [markdown]
# 1.  **Sequential Chain Practice (LCEL):**
#     You have three components: `R_topic_prompt`, `R_model`, and `R_parser`. Write the most concise Python code (using LCEL) to link them sequentially and invoke the chain with the input `{"topic": "Physics"}`.

# %%
load_dotenv()

model = ChatOpenAI(model="gpt-5-nano")

parser = StrOutputParser()

R_topic_prompt = PromptTemplate(
    template="Write a note about the most underrated thing about the {topic}",
    input_variables=['topic']
)

chain = RunnableSequence(R_topic_prompt, model, parser)
print(chain.invoke({"topic": "Physics"}))
# Out:
# The most underrated thing about physics is its love of idealized models—the art of simplifying the world just enough to see what matters.
#
# In everyday life, detail feels essential. But physics teaches that, to understand how things move, vibrate, or interact, you often gain more by stripping away the noise and focusing on the core ingredients. A frictionless plane, a point particle, a perfectly rigid rod, a harmonic oscillator: these aren’t “how things really are” in every situation, but they are the keys to revealing the underlying ideas. From these tiny, abstract models, we learn cause and effect, relationships between quantities, and the limits of our predictions.
#
# This idea matters for several reasons. First, it gives us predictive power without becoming paralyzed by complexity. The laws governing motion, energy, and forces emerge from a handful of idealizations, and those laws apply far more broadly than the dusty setup where they were first written. The harmonic oscillator, for example, appears in springs, pendulums, circuits, and even some ecological dynamics—because the same mathematics captures a universal pattern of restoring force and simple motion.
#
# Second, simple models teach the craft of thinking. Expert physics isn’t about memorizing a pile of equations; it’s about recognizing which variables to keep, which to ignore, and how to connect them. It’s about formulating a problem in a minimal framework, solving it cleanly, and then testing how far the result travels across contexts. This is the mental habit that leads to general principles—conservation laws, symmetries, scaling—and to new physics when reality refuses to fit the model.
#
# Third, the beauty of physics often lies in its humility. When a model fails to describe a phenomenon, that failure points to new physics or the need for refinement. The strength of a theory isn't that it’s perfect, but that it tells you where its assumptions matter and how far its predictions can reach. The practice of knowing the limits is, in itself, a crucial insight, one that keeps science honest and curious.
#
# To appreciate this underrated aspect, try a small exercise in your thinking: pick a familiar system, strip it to its essential elements, and ask what must be true independent of the messy details. For a swinging pendulum, you discover a simple relation between period and length (for small angles); for orbital motion, a few clean constants dictate the dance of planets. These aren’t accidents—they’re the fingerprints of simple models at work.
#
# In education and research, leaning into this mindset can be transformative. It helps students grasp physics not as a library of facts to memorize, but as a toolkit for thinking about the natural world. It reminds us to value intuition, to test ideas against data, and to celebrate the elegance that arises when a few idealizations align with reality.
#
# So, the most underrated thing about physics is not a breakthrough formula or a famous experiment, but the disciplined elegance of simplifying the universe just enough to extract its essence. That is the core habit of physicists: to build simple, powerful models that illuminate the complex, and to know precisely when those models must step aside for a more complete description.
